# %%
import json
from tqdm import tqdm
from bs4 import BeautifulSoup
import xml.etree.ElementTree as ElT
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import pandas as pd
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500


from pathlib import Path
import sys
sys.path.append("..")
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

df = pd.read_csv(Path('./writers.csv'))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# 손쉬운 처리를 위해 타입을 바꿉니다
df["AnswerCount"] = df["AnswerCount"].fillna(-1)
df["AnswerCount"] = df["AnswerCount"].astype(int)
df["PostTypeId"] = df["PostTypeId"].astype(int)
df["Id"] = df["Id"].astype(int)
df.set_index("Id", inplace=True, drop=False)

# 포스트의 길이를 추가합니다.
df["full_text"] = df["Title"].str.cat(df["body_text"], sep=" ", na_rep="")
df["text_len"] = df["full_text"].str.len()

# 질문은 포스트 타입이 1입니다
df["is_question"] = df["PostTypeId"] == 1

# %%
import missingno as msno

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34330 entries, 1 to 42885
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             34330 non-null  int64
#  1   AcceptedAnswerId       4124 non-null   float64
#  2   AnswerCount            34330 non-null  int64
#  3   Body                   34256 non-null  object
#  4   ClosedDate             969 non-null    object
#  5   CommentCount           34330 non-null  int64
#  6   CommunityOwnedDate     186 non-null    object
#  7   CreationDate           34330 non-null  object
#  8   FavoriteCount          3307 non-null   float64
#  9   Id                     34330 non-null  int64
#  10  LastActivityDate       34330 non-null  object
#  11  LastEditDate           11201 non-null  object
#  12  LastEditorDisplayName  614 non-null    object
#  13  LastEditorUserId       10648 non-null  float64
#  14  OwnerDisplayName       1976 non-null   object
#  15  OwnerUserId            32792 non-null  float64
#  16  ParentId               25679 non-null  float64
#  17  PostTypeId             34330 non-null  int64
#  18  Score                  34330 non-null  int64
#  19  Tags                   7971 non-null   object
#  20  Title                  7971 non-null   object
#  21  ViewCount              7971 non-null   float64
#  22  body_text              34256 non-null  object
#  23  full_text              34330 non-null  object
#  24  text_len               34330 non-null  int64
#  25  is_question            34330 non-null  bool
# dtypes: bool(1), float64(6), int64(7), object(12)
# memory usage: 6.8+ MB

# %%
df[df['Body'].isna()]
# Out:
#        Unnamed: 0  AcceptedAnswerId  AnswerCount Body ClosedDate  \
# Id
# 2145         1959               NaN           -1  NaN        NaN
# 2147         1961               NaN           -1  NaN        NaN
# 2215         2029               NaN           -1  NaN        NaN
# 2218         2032               NaN           -1  NaN        NaN
# 2225         2039               NaN           -1  NaN        NaN
# 2227         2041               NaN           -1  NaN        NaN
# 2233         2047               NaN           -1  NaN        NaN
# 2238         2052               NaN           -1  NaN        NaN
# 3138         2850               NaN           -1  NaN        NaN
# 5148         4658               NaN           -1  NaN        NaN
# 5150         4660               NaN           -1  NaN        NaN
# 5152         4662               NaN           -1  NaN        NaN
# 5162         4672               NaN           -1  NaN        NaN
# 5551         5021               NaN           -1  NaN        NaN
# 5553         5023               NaN           -1  NaN        NaN
# 5555         5025               NaN           -1  NaN        NaN
# 5797         5242               NaN           -1  NaN        NaN
# 5832         5277               NaN           -1  NaN        NaN
# 6261         5646               NaN           -1  NaN        NaN
# 6313         5681               NaN           -1  NaN        NaN
# 6360         5720               NaN           -1  NaN        NaN
# 6362         5722               NaN           -1  NaN        NaN
# 6364         5724               NaN           -1  NaN        NaN
# 8125         7195               NaN           -1  NaN        NaN
# 8481         7502               NaN           -1  NaN        NaN
# 8731         7717               NaN           -1  NaN        NaN
# 9915         8716               NaN           -1  NaN        NaN
# 9978         8769               NaN           -1  NaN        NaN
# 9980         8771               NaN           -1  NaN        NaN
# 9982         8773               NaN           -1  NaN        NaN
# 10157        8934               NaN           -1  NaN        NaN
# 12928       10394               NaN           -1  NaN        NaN
# 16614       11798               NaN           -1  NaN        NaN
# 16767       11931               NaN           -1  NaN        NaN
# 17918       12874               NaN           -1  NaN        NaN
# 17920       12876               NaN           -1  NaN        NaN
# 17924       12880               NaN           -1  NaN        NaN
# 18113       13039               NaN           -1  NaN        NaN
# 18631       13477               NaN           -1  NaN        NaN
# 19265       14027               NaN           -1  NaN        NaN
# 21584       16061               NaN           -1  NaN        NaN
# 23546       16866               NaN           -1  NaN        NaN
# 24773       17914               NaN           -1  NaN        NaN
# 25973       18940               NaN           -1  NaN        NaN
# 25975       18942               NaN           -1  NaN        NaN
# 25976       18943               NaN           -1  NaN        NaN
# 26248       19194               NaN           -1  NaN        NaN
# 27648       20448               NaN           -1  NaN        NaN
# 31270       23690               NaN           -1  NaN        NaN
# 31512       23911               NaN           -1  NaN        NaN
# 33618       25879               NaN           -1  NaN        NaN
# 33622       25883               NaN           -1  NaN        NaN
# 33624       25885               NaN           -1  NaN        NaN
# 33676       25931               NaN           -1  NaN        NaN
# 34225       26438               NaN           -1  NaN        NaN
# 34236       26449               NaN           -1  NaN        NaN
# 34238       26451               NaN           -1  NaN        NaN
# 34240       26453               NaN           -1  NaN        NaN
# 34968       27124               NaN           -1  NaN        NaN
# 36554       28626               NaN           -1  NaN        NaN
# 37125       29145               NaN           -1  NaN        NaN
# 37794       29767               NaN           -1  NaN        NaN
# 38702       30597               NaN           -1  NaN        NaN
# 38869       30741               NaN           -1  NaN        NaN
# 39531       31326               NaN           -1  NaN        NaN
# 39533       31328               NaN           -1  NaN        NaN
# 39957       31712               NaN           -1  NaN        NaN
# 40902       32535               NaN           -1  NaN        NaN
# 41952       33453               NaN           -1  NaN        NaN
# 42223       33706               NaN           -1  NaN        NaN
# 42549       34006               NaN           -1  NaN        NaN
# 42551       34008               NaN           -1  NaN        NaN
# 42629       34085               NaN           -1  NaN        NaN
# 42787       34237               NaN           -1  NaN        NaN
#
#        CommentCount CommunityOwnedDate             CreationDate  \
# Id
# 2145              0                NaN  2011-03-22T19:49:56.600
# 2147              0                NaN  2011-03-22T19:51:05.897
# 2215              0                NaN  2011-03-24T19:35:10.353
# 2218              0                NaN  2011-03-24T19:41:38.677
# 2225              0                NaN  2011-03-24T19:58:59.833
# 2227              0                NaN  2011-03-24T20:05:07.753
# 2233              0                NaN  2011-03-24T20:22:44.603
# 2238              0                NaN  2011-03-24T20:38:42.200
# 3138              0                NaN  2011-06-19T20:18:13.253
# 5148              0                NaN  2012-03-03T21:24:29.283
# 5150              0                NaN  2012-03-03T21:32:34.593
# 5152              0                NaN  2012-03-03T21:34:05.107
# 5162              0                NaN  2012-03-06T05:06:18.340
# 5551              0                NaN  2012-05-01T03:58:38.053
# 5553              0                NaN  2012-05-01T04:00:25.867
# 5555              0                NaN  2012-05-01T04:01:33.213
# 5797              0                NaN  2012-05-31T21:53:43.603
# 5832              0                NaN  2012-06-03T01:46:28.573
# 6261              0                NaN  2012-08-25T22:24:34.940
# 6313              0                NaN  2012-09-09T05:10:35.357
# 6360              0                NaN  2012-09-19T05:17:35.503
# 6362              0                NaN  2012-09-19T05:18:18.670
# 6364              0                NaN  2012-09-19T05:18:54.503
# 8125              0                NaN  2013-06-11T15:55:30.707
# 8481              0                NaN  2013-07-24T02:22:24.207
# 8731              0                NaN  2013-08-29T10:47:45.753
# 9915              0                NaN  2014-01-04T23:43:51.240
# 9978              0                NaN  2014-01-09T17:20:20.917
# 9980              0                NaN  2014-01-09T17:22:27.567
# 9982              0                NaN  2014-01-09T17:23:50.717
# 10157             0                NaN  2014-01-28T02:29:08.250
# 12928             0                NaN  2014-09-19T05:14:47.983
# 16614             0                NaN  2015-03-24T18:56:21.290
# 16767             0                NaN  2015-04-09T00:34:52.980
# 17918             0                NaN  2015-06-27T14:29:49.817
# 17920             0                NaN  2015-06-27T14:34:20.473
# 17924             0                NaN  2015-06-27T14:45:37.177
# 18113             0                NaN  2015-07-09T19:28:27.890
# 18631             0                NaN  2015-08-13T17:36:33.167
# 19265             0                NaN  2015-10-08T15:43:45.757
# 21584             0                NaN  2016-04-03T00:58:02.697
# 23546             0                NaN  2016-06-24T20:34:47.840
# 24773             0                NaN  2016-09-27T08:59:47.427
# 25973             0                NaN  2017-01-10T19:32:21.287
# 25975             0                NaN  2017-01-10T19:34:59.120
# 25976             0                NaN  2017-01-10T19:34:59.120
# 26248             0                NaN  2017-01-24T16:52:06.440
# 27648             0                NaN  2017-04-21T17:03:01.877
# 31270             0                NaN  2017-11-06T16:18:19.400
# 31512             0                NaN  2017-11-17T23:54:37.853
# 33618             0                NaN  2018-02-20T16:14:27.410
# 33622             0                NaN  2018-02-20T16:23:12.540
# 33624             0                NaN  2018-02-20T16:24:48.927
# 33676             0                NaN  2018-02-21T16:27:02.373
# 34225             0                NaN  2018-03-12T18:53:50.403
# 34236             0                NaN  2018-03-12T21:49:22.623
# 34238             0                NaN  2018-03-12T21:54:23.803
# 34240             0                NaN  2018-03-12T21:57:55.510
# 34968             0                NaN  2018-04-11T05:16:59.860
# 36554             0                NaN  2018-05-30T12:55:01.670
# 37125             0                NaN  2018-06-21T14:31:26.603
# 37794             0                NaN  2018-07-23T09:02:06.137
# 38702             0                NaN  2018-09-05T10:45:41.983
# 38869             0                NaN  2018-09-12T14:14:23.750
# 39531             0                NaN  2018-10-19T14:40:59.737
# 39533             0                NaN  2018-10-19T14:45:08.407
# 39957             0                NaN  2018-11-07T10:37:35.183
# 40902             0                NaN  2018-12-26T12:40:16.647
# 41952             0                NaN  2019-02-05T09:24:48.960
# 42223             0                NaN  2019-02-14T09:42:01.813
# 42549             0                NaN  2019-02-24T05:18:39.920
# 42551             0                NaN  2019-02-24T05:26:20.740
# 42629             0                NaN  2019-02-25T22:45:38.457
# 42787             0                NaN  2019-03-01T01:51:56.043
#
#        FavoriteCount     Id         LastActivityDate             LastEditDate  \
# Id
# 2145             NaN   2145  2011-03-22T19:49:56.600  2011-03-22T19:49:56.600
# 2147             NaN   2147  2011-03-22T19:51:05.897  2011-03-22T19:51:05.897
# 2215             NaN   2215  2011-03-24T19:35:10.353  2011-03-24T19:35:10.353
# 2218             NaN   2218  2011-03-24T19:41:38.677  2011-03-24T19:41:38.677
# 2225             NaN   2225  2011-03-24T19:58:59.833  2011-03-24T19:58:59.833
# 2227             NaN   2227  2011-03-24T20:05:07.753  2011-03-24T20:05:07.753
# 2233             NaN   2233  2011-03-24T20:22:44.603  2011-03-24T20:22:44.603
# 2238             NaN   2238  2011-03-24T20:38:42.200  2011-03-24T20:38:42.200
# 3138             NaN   3138  2011-06-19T20:18:13.253  2011-06-19T20:18:13.253
# 5148             NaN   5148  2012-03-03T21:24:29.283  2012-03-03T21:24:29.283
# 5150             NaN   5150  2012-03-03T21:32:34.593  2012-03-03T21:32:34.593
# 5152             NaN   5152  2012-03-03T21:34:05.107  2012-03-03T21:34:05.107
# 5162             NaN   5162  2012-03-06T05:06:18.340  2012-03-06T05:06:18.340
# 5551             NaN   5551  2012-05-01T03:58:38.053  2012-05-01T03:58:38.053
# 5553             NaN   5553  2012-05-01T04:00:25.867  2012-05-01T04:00:25.867
# 5555             NaN   5555  2012-05-01T04:01:33.213  2012-05-01T04:01:33.213
# 5797             NaN   5797  2012-05-31T21:53:43.603  2012-05-31T21:53:43.603
# 5832             NaN   5832  2018-07-12T17:58:00.200  2018-07-12T17:58:00.200
# 6261             NaN   6261  2012-08-25T22:24:34.940  2012-08-25T22:24:34.940
# 6313             NaN   6313  2012-09-09T05:10:35.357  2012-09-09T05:10:35.357
# 6360             NaN   6360  2012-09-19T05:17:35.503  2012-09-19T05:17:35.503
# 6362             NaN   6362  2012-09-19T05:18:18.670  2012-09-19T05:18:18.670
# 6364             NaN   6364  2012-09-19T05:18:54.503  2012-09-19T05:18:54.503
# 8125             NaN   8125  2013-06-11T15:55:30.707  2013-06-11T15:55:30.707
# 8481             NaN   8481  2013-07-24T02:22:24.207  2013-07-24T02:22:24.207
# 8731             NaN   8731  2013-08-29T10:47:45.753  2013-08-29T10:47:45.753
# 9915             NaN   9915  2014-01-04T23:43:51.240  2014-01-04T23:43:51.240
# 9978             NaN   9978  2014-01-09T17:20:20.917  2014-01-09T17:20:20.917
# 9980             NaN   9980  2014-01-09T17:22:27.567  2014-01-09T17:22:27.567
# 9982             NaN   9982  2014-01-09T17:23:50.717  2014-01-09T17:23:50.717
# 10157            NaN  10157  2014-01-28T02:29:08.250  2014-01-28T02:29:08.250
# 12928            NaN  12928  2014-09-19T05:14:47.983  2014-09-19T05:14:47.983
# 16614            NaN  16614  2015-03-24T18:56:21.290  2015-03-24T18:56:21.290
# 16767            NaN  16767  2015-04-09T00:34:52.980  2015-04-09T00:34:52.980
# 17918            NaN  17918  2015-06-27T14:29:49.817  2015-06-27T14:29:49.817
# 17920            NaN  17920  2015-06-27T14:34:20.473  2015-06-27T14:34:20.473
# 17924            NaN  17924  2015-06-27T14:45:37.177  2015-06-27T14:45:37.177
# 18113            NaN  18113  2015-07-09T19:28:27.890  2015-07-09T19:28:27.890
# 18631            NaN  18631  2015-08-13T17:36:33.167  2015-08-13T17:36:33.167
# 19265            NaN  19265  2015-10-08T15:43:45.757  2015-10-08T15:43:45.757
# 21584            NaN  21584  2016-04-03T00:58:02.697  2016-04-03T00:58:02.697
# 23546            NaN  23546  2016-06-24T20:34:47.840  2016-06-24T20:34:47.840
# 24773            NaN  24773  2016-09-27T08:59:47.427  2016-09-27T08:59:47.427
# 25973            NaN  25973  2017-01-10T19:32:21.287  2017-01-10T19:32:21.287
# 25975            NaN  25975  2017-01-10T19:34:59.120  2017-01-10T19:34:59.120
# 25976            NaN  25976  2017-01-10T19:34:59.120  2017-01-10T19:34:59.120
# 26248            NaN  26248  2017-01-24T16:52:06.440  2017-01-24T16:52:06.440
# 27648            NaN  27648  2017-04-21T17:03:01.877  2017-04-21T17:03:01.877
# 31270            NaN  31270  2017-11-06T16:18:19.400  2017-11-06T16:18:19.400
# 31512            NaN  31512  2017-11-17T23:54:37.853  2017-11-17T23:54:37.853
# 33618            NaN  33618  2018-02-20T16:14:27.410  2018-02-20T16:14:27.410
# 33622            NaN  33622  2018-02-20T16:23:12.540  2018-02-20T16:23:12.540
# 33624            NaN  33624  2018-02-20T16:24:48.927  2018-02-20T16:24:48.927
# 33676            NaN  33676  2018-02-21T16:27:02.373  2018-02-21T16:27:02.373
# 34225            NaN  34225  2018-03-12T18:53:50.403  2018-03-12T18:53:50.403
# 34236            NaN  34236  2018-03-12T21:49:22.623  2018-03-12T21:49:22.623
# 34238            NaN  34238  2018-03-12T21:54:23.803  2018-03-12T21:54:23.803
# 34240            NaN  34240  2018-03-12T21:57:55.510  2018-03-12T21:57:55.510
# 34968            NaN  34968  2018-04-11T05:16:59.860  2018-04-11T05:16:59.860
# 36554            NaN  36554  2018-05-30T12:55:01.670  2018-05-30T12:55:01.670
# 37125            NaN  37125  2018-06-21T14:31:26.603  2018-06-21T14:31:26.603
# 37794            NaN  37794  2018-07-23T09:02:06.137  2018-07-23T09:02:06.137
# 38702            NaN  38702  2018-09-05T10:45:41.983  2018-09-05T10:45:41.983
# 38869            NaN  38869  2018-09-12T14:14:23.750  2018-09-12T14:14:23.750
# 39531            NaN  39531  2018-10-19T14:40:59.737  2018-10-19T14:40:59.737
# 39533            NaN  39533  2018-10-19T14:45:08.407  2018-10-19T14:45:08.407
# 39957            NaN  39957  2018-11-07T10:37:35.183  2018-11-07T10:37:35.183
# 40902            NaN  40902  2018-12-26T12:40:16.647  2018-12-26T12:40:16.647
# 41952            NaN  41952  2019-02-05T09:24:48.960  2019-02-05T09:24:48.960
# 42223            NaN  42223  2019-02-14T09:42:01.813  2019-02-14T09:42:01.813
# 42549            NaN  42549  2019-02-24T05:18:39.920  2019-02-24T05:18:39.920
# 42551            NaN  42551  2019-02-24T05:26:20.740  2019-02-24T05:26:20.740
# 42629            NaN  42629  2019-02-25T22:45:38.457  2019-02-25T22:45:38.457
# 42787            NaN  42787  2019-03-01T01:51:56.043  2019-03-01T01:51:56.043
#
#       LastEditorDisplayName  LastEditorUserId OwnerDisplayName  OwnerUserId  \
# Id
# 2145                    NaN              20.0              NaN         20.0
# 2147                    NaN              20.0              NaN         20.0
# 2215                    NaN              -1.0              NaN         -1.0
# 2218                    NaN              -1.0              NaN         -1.0
# 2225                    NaN              -1.0              NaN         -1.0
# 2227                    NaN              -1.0              NaN         -1.0
# 2233                    NaN              -1.0              NaN         -1.0
# 2238                    NaN              -1.0              NaN         -1.0
# 3138                    NaN              -1.0              NaN         -1.0
# 5148                    NaN              26.0              NaN         26.0
# 5150                    NaN              26.0              NaN         26.0
# 5152                    NaN              26.0              NaN         26.0
# 5162                    NaN              26.0              NaN         26.0
# 5551                    NaN              26.0              NaN         26.0
# 5553                    NaN              26.0              NaN         26.0
# 5555                    NaN              26.0              NaN         26.0
# 5797                    NaN            1046.0              NaN       1046.0
# 5832                    NaN              26.0              NaN        553.0
# 6261                    NaN              26.0              NaN         26.0
# 6313                    NaN              26.0              NaN         26.0
# 6360                    NaN              26.0              NaN         26.0
# 6362                    NaN              26.0              NaN         26.0
# 6364                    NaN              26.0              NaN         26.0
# 8125                    NaN              -1.0              NaN         -1.0
# 8481                    NaN            1993.0              NaN       1993.0
# 8731                    NaN              -1.0              NaN         -1.0
# 9915                    NaN              26.0              NaN         26.0
# 9978                    NaN              26.0              NaN         26.0
# 9980                    NaN              26.0              NaN         26.0
# 9982                    NaN              26.0              NaN         26.0
# 10157                   NaN              -1.0              NaN         -1.0
# 12928                   NaN            1046.0              NaN       1046.0
# 16614                   NaN              -1.0              NaN         -1.0
# 16767                   NaN              -1.0              NaN         -1.0
# 17918                   NaN              -1.0              NaN         -1.0
# 17920                   NaN              -1.0              NaN         -1.0
# 17924                   NaN              -1.0              NaN         -1.0
# 18113                   NaN              -1.0              NaN         -1.0
# 18631                   NaN              -1.0              NaN         -1.0
# 19265                   NaN              -1.0              NaN         -1.0
# 21584                   NaN              26.0              NaN         26.0
# 23546                   NaN            1993.0              NaN       1993.0
# 24773              user5645               NaN         user5645          NaN
# 25973                   NaN              -1.0              NaN         -1.0
# 25975                   NaN              -1.0              NaN         -1.0
# 25976                   NaN              -1.0              NaN         -1.0
# 26248                   NaN              -1.0              NaN         -1.0
# 27648                   NaN              -1.0              NaN         -1.0
# 31270                   NaN              -1.0              NaN         -1.0
# 31512                   NaN           10394.0              NaN      10394.0
# 33618                   NaN            1993.0              NaN       1993.0
# 33622                   NaN            1993.0              NaN       1993.0
# 33624                   NaN            1993.0              NaN       1993.0
# 33676                   NaN              -1.0              NaN         -1.0
# 34225                   NaN              -1.0              NaN         -1.0
# 34236                   NaN              -1.0              NaN         -1.0
# 34238                   NaN              -1.0              NaN         -1.0
# 34240                   NaN              -1.0              NaN         -1.0
# 34968             user29032               NaN        user29032          NaN
# 36554                   NaN              -1.0              NaN         -1.0
# 37125                   NaN              -1.0              NaN         -1.0
# 37794                   NaN            1046.0              NaN       1046.0
# 38702                   NaN              -1.0              NaN         -1.0
# 38869                   NaN              -1.0              NaN         -1.0
# 39531                   NaN              -1.0              NaN         -1.0
# 39533                   NaN              -1.0              NaN         -1.0
# 39957                   NaN              -1.0              NaN         -1.0
# 40902                   NaN           25517.0              NaN      25517.0
# 41952                   NaN           25517.0              NaN      25517.0
# 42223                   NaN           25517.0              NaN      25517.0
# 42549                   NaN           32946.0              NaN      32946.0
# 42551                   NaN           32946.0              NaN      32946.0
# 42629                   NaN           32946.0              NaN      32946.0
# 42787                   NaN            1993.0              NaN       1993.0
#
#        ParentId  PostTypeId  Score Tags Title  ViewCount body_text full_text  \
# Id
# 2145        NaN           5      0  NaN   NaN        NaN       NaN
# 2147        NaN           5      0  NaN   NaN        NaN       NaN
# 2215        NaN           5      0  NaN   NaN        NaN       NaN
# 2218        NaN           5      0  NaN   NaN        NaN       NaN
# 2225        NaN           5      0  NaN   NaN        NaN       NaN
# 2227        NaN           5      0  NaN   NaN        NaN       NaN
# 2233        NaN           5      0  NaN   NaN        NaN       NaN
# 2238        NaN           5      0  NaN   NaN        NaN       NaN
# 3138        NaN           5      0  NaN   NaN        NaN       NaN
# 5148        NaN           5      0  NaN   NaN        NaN       NaN
# 5150        NaN           5      0  NaN   NaN        NaN       NaN
# 5152        NaN           5      0  NaN   NaN        NaN       NaN
# 5162        NaN           5      0  NaN   NaN        NaN       NaN
# 5551        NaN           5      0  NaN   NaN        NaN       NaN
# 5553        NaN           5      0  NaN   NaN        NaN       NaN
# 5555        NaN           5      0  NaN   NaN        NaN       NaN
# 5797        NaN           5      0  NaN   NaN        NaN       NaN
# 5832        NaN           5      0  NaN   NaN        NaN       NaN
# 6261        NaN           5      0  NaN   NaN        NaN       NaN
# 6313        NaN           5      0  NaN   NaN        NaN       NaN
# 6360        NaN           5      0  NaN   NaN        NaN       NaN
# 6362        NaN           5      0  NaN   NaN        NaN       NaN
# 6364        NaN           5      0  NaN   NaN        NaN       NaN
# 8125        NaN           5      0  NaN   NaN        NaN       NaN
# 8481        NaN           5      0  NaN   NaN        NaN       NaN
# 8731        NaN           5      0  NaN   NaN        NaN       NaN
# 9915        NaN           5      0  NaN   NaN        NaN       NaN
# 9978        NaN           5      0  NaN   NaN        NaN       NaN
# 9980        NaN           5      0  NaN   NaN        NaN       NaN
# 9982        NaN           5      0  NaN   NaN        NaN       NaN
# 10157       NaN           5      0  NaN   NaN        NaN       NaN
# 12928       NaN           5      0  NaN   NaN        NaN       NaN
# 16614       NaN           5      0  NaN   NaN        NaN       NaN
# 16767       NaN           5      0  NaN   NaN        NaN       NaN
# 17918       NaN           5      0  NaN   NaN        NaN       NaN
# 17920       NaN           5      0  NaN   NaN        NaN       NaN
# 17924       NaN           5      0  NaN   NaN        NaN       NaN
# 18113       NaN           5      0  NaN   NaN        NaN       NaN
# 18631       NaN           5      0  NaN   NaN        NaN       NaN
# 19265       NaN           5      0  NaN   NaN        NaN       NaN
# 21584       NaN           5      0  NaN   NaN        NaN       NaN
# 23546       NaN           5      0  NaN   NaN        NaN       NaN
# 24773       NaN           5      0  NaN   NaN        NaN       NaN
# 25973       NaN           5      0  NaN   NaN        NaN       NaN
# 25975       NaN           5      0  NaN   NaN        NaN       NaN
# 25976       NaN           4      0  NaN   NaN        NaN       NaN
# 26248       NaN           5      0  NaN   NaN        NaN       NaN
# 27648       NaN           5      0  NaN   NaN        NaN       NaN
# 31270       NaN           5      0  NaN   NaN        NaN       NaN
# 31512       NaN           5      0  NaN   NaN        NaN       NaN
# 33618       NaN           5      0  NaN   NaN        NaN       NaN
# 33622       NaN           5      0  NaN   NaN        NaN       NaN
# 33624       NaN           5      0  NaN   NaN        NaN       NaN
# 33676       NaN           5      0  NaN   NaN        NaN       NaN
# 34225       NaN           5      0  NaN   NaN        NaN       NaN
# 34236       NaN           5      0  NaN   NaN        NaN       NaN
# 34238       NaN           5      0  NaN   NaN        NaN       NaN
# 34240       NaN           5      0  NaN   NaN        NaN       NaN
# 34968       NaN           5      0  NaN   NaN        NaN       NaN
# 36554       NaN           5      0  NaN   NaN        NaN       NaN
# 37125       NaN           5      0  NaN   NaN        NaN       NaN
# 37794       NaN           5      0  NaN   NaN        NaN       NaN
# 38702       NaN           5      0  NaN   NaN        NaN       NaN
# 38869       NaN           5      0  NaN   NaN        NaN       NaN
# 39531       NaN           5      0  NaN   NaN        NaN       NaN
# 39533       NaN           5      0  NaN   NaN        NaN       NaN
# 39957       NaN           5      0  NaN   NaN        NaN       NaN
# 40902       NaN           5      0  NaN   NaN        NaN       NaN
# 41952       NaN           5      0  NaN   NaN        NaN       NaN
# 42223       NaN           5      0  NaN   NaN        NaN       NaN
# 42549       NaN           5      0  NaN   NaN        NaN       NaN
# 42551       NaN           5      0  NaN   NaN        NaN       NaN
# 42629       NaN           5      0  NaN   NaN        NaN       NaN
# 42787       NaN           5      0  NaN   NaN        NaN       NaN
#
#        text_len  is_question
# Id
# 2145          1        False
# 2147          1        False
# 2215          1        False
# 2218          1        False
# 2225          1        False
# 2227          1        False
# 2233          1        False
# 2238          1        False
# 3138          1        False
# 5148          1        False
# 5150          1        False
# 5152          1        False
# 5162          1        False
# 5551          1        False
# 5553          1        False
# 5555          1        False
# 5797          1        False
# 5832          1        False
# 6261          1        False
# 6313          1        False
# 6360          1        False
# 6362          1        False
# 6364          1        False
# 8125          1        False
# 8481          1        False
# 8731          1        False
# 9915          1        False
# 9978          1        False
# 9980          1        False
# 9982          1        False
# 10157         1        False
# 12928         1        False
# 16614         1        False
# 16767         1        False
# 17918         1        False
# 17920         1        False
# 17924         1        False
# 18113         1        False
# 18631         1        False
# 19265         1        False
# 21584         1        False
# 23546         1        False
# 24773         1        False
# 25973         1        False
# 25975         1        False
# 25976         1        False
# 26248         1        False
# 27648         1        False
# 31270         1        False
# 31512         1        False
# 33618         1        False
# 33622         1        False
# 33624         1        False
# 33676         1        False
# 34225         1        False
# 34236         1        False
# 34238         1        False
# 34240         1        False
# 34968         1        False
# 36554         1        False
# 37125         1        False
# 37794         1        False
# 38702         1        False
# 38869         1        False
# 39531         1        False
# 39533         1        False
# 39957         1        False
# 40902         1        False
# 41952         1        False
# 42223         1        False
# 42549         1        False
# 42551         1        False
# 42629         1        False
# 42787         1        False

# %%
df = df[df['PostTypeId'].isin([1, 2])]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33650 entries, 1 to 42885
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             33650 non-null  int64
#  1   AcceptedAnswerId       4124 non-null   float64
#  2   AnswerCount            33650 non-null  int64
#  3   Body                   33650 non-null  object
#  4   ClosedDate             969 non-null    object
#  5   CommentCount           33650 non-null  int64
#  6   CommunityOwnedDate     186 non-null    object
#  7   CreationDate           33650 non-null  object
#  8   FavoriteCount          3307 non-null   float64
#  9   Id                     33650 non-null  int64
#  10  LastActivityDate       33650 non-null  object
#  11  LastEditDate           10521 non-null  object
#  12  LastEditorDisplayName  606 non-null    object
#  13  LastEditorUserId       9975 non-null   float64
#  14  OwnerDisplayName       1971 non-null   object
#  15  OwnerUserId            32117 non-null  float64
#  16  ParentId               25679 non-null  float64
#  17  PostTypeId             33650 non-null  int64
#  18  Score                  33650 non-null  int64
#  19  Tags                   7971 non-null   object
#  20  Title                  7971 non-null   object
#  21  ViewCount              7971 non-null   float64
#  22  body_text              33650 non-null  object
#  23  full_text              33650 non-null  object
#  24  text_len               33650 non-null  int64
#  25  is_question            33650 non-null  bool
# dtypes: bool(1), float64(6), int64(7), object(12)
# memory usage: 6.7+ MB

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
questions_with_accepted_answers = df[df["is_question"] & ~(df["AcceptedAnswerId"].isna())]
q_and_a = questions_with_accepted_answers.join(df[["body_text"]], on="AcceptedAnswerId", how="left", rsuffix="_answer")

# %%
q_and_a[['body_text', 'body_text_answer']][:3]
# Out:
#                                                                                                                                                                                                                                                                                                             body_text  \
# Id
# 1   I've always wanted to start writing (in a totally amateur way), but whenever I want to start something I instantly get blocked having a lot of questions and doubts.\nAre there some resources on how to start becoming a writer?\nI'm thinking something with tips and easy exercises to get the ball rolling.\n
# 2                                                 What kind of story is better suited for each point of view? Are there advantages or disadvantages inherent to them?\nFor example, writing in the first person you are always following a character, while in the third person you can "jump" between story lines.\n
# 3                                                                                                                                                                                                                         I finished my novel, and everyone I've talked to says I need an agent. How do I find one?\n
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        body_text_answer
# Id
# 1   When I'm thinking about where I learned most how to write, I think that reading was the most important guide to me. This may sound silly, but by reading good written newspaper articles (facts, opinions, scientific articles and most of all, criticisms of films and music), I learned how others did the job, what works and what doesn't. In my own writing, I try to mimic other people's styles that I liked. Moreover, I learn new things by reading, giving me a broader background that I need when re...
# 2   With a story in first person, you are intending the reader to become much more attached to the main character.  Since the reader sees what that character sees and feels what that character feels, the reader will have an emotional investment in that character.  Third person does not have this close tie; a reader can become emotionally invested but it will not be as strong as it will be in first person.\nContrarily, you cannot have multiple point characters when you use first person without ex...
# 3   Try and find a list of agents who write in your genre. Check out their websites!\nFind out if they are accepting new clients. If they aren't, then check out another agent. But if they are, try sending them a few chapters from your story, a brief, and a short cover letter asking them to represent you.\nIn the cover letter mention your previous publication credits. If sent via post, then I suggest you give them a means of reply, whether it be an email or a stamped, addressed envelope.\nAgents ...

# %%
df = df.join(df[["Id", "Title", "body_text", "text_len", "Score", "AcceptedAnswerId"]], on="ParentId", how="left", rsuffix='_question')

# %%
df[df["Id_question"] ==1].head()
# Out:
#      Unnamed: 0  AcceptedAnswerId  AnswerCount  \
# Id
# 8             5               NaN           -1
# 15           10               NaN           -1
# 79           65               NaN           -1
# 123         106               NaN           -1
# 254         231               NaN           -1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Body  \
# Id
# 8                                                                                                                                                                                                                                                                                                                                                          <p>BeginningWriters.com has some good articles for beginning writers.</p>\n\n<p><a href="http://beginningwriters.com/">http://beginningwriters.com/</a></p>\n
# 15   <p>When I'm thinking about where I learned most how to write, I think that <em>reading</em> was the most important guide to me. This may sound silly, but by reading good written newspaper articles (facts, opinions, scientific articles and most of all, criticisms of films and music), I learned how others did the job, what works and what doesn't. In my own writing, I try to mimic other people's styles that I liked. Moreover, I learn new things by reading, giving me a broader background that I ...
# 79                                                                                                                                                                                                                                                                                                              <p>I particularly like <a href="http://www.advancedfictionwriting.com/art/snowflake.php" rel="nofollow" rel="nofollow">The Snowflake Method</a> and most of what Randy writes, including his book.</p>\n
# 123           <p>Reading a lot and loving to read are most important of course, but have you tried writing-related podcasts?</p>\n\n<p><strong><a href="http://www.writingexcuses.com/" rel="nofollow">Writing Excuses</a></strong> got me into writing fiction again. It's a short podcast about how to write fiction well and how to "break in" to the industry, from 3 guys who do and did. (I wrote a bit more about it on <a href="http://mgowen.com/2010/11/12/writing-excuses/" rel="nofollow">my blog</a>)</p>\n
# 254                                                                                                                                                                                                                                                                                                                                                                                              <p><a href="http://www.writersdigest.com/GeneralMenu/" rel="nofollow">Writer's Digest</a> has many good articles.</p>\n
#
#     ClosedDate  CommentCount CommunityOwnedDate             CreationDate  \
# Id
# 8          NaN             0                NaN  2010-11-18T20:45:45.533
# 15         NaN             3                NaN  2010-11-18T20:50:16.683
# 79         NaN             0                NaN  2010-11-18T23:19:33.157
# 123        NaN             0                NaN  2010-11-19T04:25:03.407
# 254        NaN             0                NaN  2010-11-19T20:09:56.347
#
#      FavoriteCount   Id         LastActivityDate             LastEditDate  \
# Id
# 8              NaN    8  2010-11-18T20:45:45.533                      NaN
# 15             NaN   15  2010-11-18T21:04:08.450  2010-11-18T21:04:08.450
# 79             NaN   79  2010-11-18T23:19:33.157                      NaN
# 123            NaN  123  2010-11-19T04:25:03.407                      NaN
# 254            NaN  254  2010-11-19T20:09:56.347                      NaN
#
#     LastEditorDisplayName  LastEditorUserId OwnerDisplayName  OwnerUserId  \
# Id
# 8                     NaN               NaN              NaN         28.0
# 15                    NaN              23.0              NaN         23.0
# 79                    NaN               NaN              NaN         21.0
# 123                   NaN               NaN              NaN         67.0
# 254                   NaN               NaN              NaN         18.0
#
#      ParentId  PostTypeId  Score Tags Title  ViewCount  \
# Id
# 8         1.0           2      9  NaN   NaN        NaN
# 15        1.0           2     15  NaN   NaN        NaN
# 79        1.0           2      5  NaN   NaN        NaN
# 123       1.0           2      3  NaN   NaN        NaN
# 254       1.0           2      2  NaN   NaN        NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                body_text  \
# Id
# 8                                                                                                                                                                                                                                                                                                                                                                                                                     BeginningWriters.com has some good articles for beginning writers.\nhttp://beginningwriters.com/\n
# 15   When I'm thinking about where I learned most how to write, I think that reading was the most important guide to me. This may sound silly, but by reading good written newspaper articles (facts, opinions, scientific articles and most of all, criticisms of films and music), I learned how others did the job, what works and what doesn't. In my own writing, I try to mimic other people's styles that I liked. Moreover, I learn new things by reading, giving me a broader background that I need when re...
# 79                                                                                                                                                                                                                                                                                                                                                                                                                         I particularly like The Snowflake Method and most of what Randy writes, including his book.\n
# 123                                                                                                                                                                                   Reading a lot and loving to read are most important of course, but have you tried writing-related podcasts?\nWriting Excuses got me into writing fiction again. It's a short podcast about how to write fiction well and how to "break in" to the industry, from 3 guys who do and did. (I wrote a bit more about it on my blog)\n
# 254                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Writer's Digest has many good articles.\n
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                full_text  \
# Id
# 8                                                                                                                                                                                                                                                                                                                                                                                                                     BeginningWriters.com has some good articles for beginning writers.\nhttp://beginningwriters.com/\n
# 15    When I'm thinking about where I learned most how to write, I think that reading was the most important guide to me. This may sound silly, but by reading good written newspaper articles (facts, opinions, scientific articles and most of all, criticisms of films and music), I learned how others did the job, what works and what doesn't. In my own writing, I try to mimic other people's styles that I liked. Moreover, I learn new things by reading, giving me a broader background that I need when r...
# 79                                                                                                                                                                                                                                                                                                                                                                                                                         I particularly like The Snowflake Method and most of what Randy writes, including his book.\n
# 123                                                                                                                                                                                   Reading a lot and loving to read are most important of course, but have you tried writing-related podcasts?\nWriting Excuses got me into writing fiction again. It's a short podcast about how to write fiction well and how to "break in" to the industry, from 3 guys who do and did. (I wrote a bit more about it on my blog)\n
# 254                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Writer's Digest has many good articles.\n
#
#      text_len  is_question  Id_question  \
# Id
# 8          97        False          1.0
# 15        962        False          1.0
# 79         93        False          1.0
# 123       321        False          1.0
# 254        41        False          1.0
#
#                                         Title_question  \
# Id
# 8    What are some online guides for starting writers?
# 15   What are some online guides for starting writers?
# 79   What are some online guides for starting writers?
# 123  What are some online guides for starting writers?
# 254  What are some online guides for starting writers?
#
#                                                                                                                                                                                                                                                                                                     body_text_question  \
# Id
# 8    I've always wanted to start writing (in a totally amateur way), but whenever I want to start something I instantly get blocked having a lot of questions and doubts.\nAre there some resources on how to start becoming a writer?\nI'm thinking something with tips and easy exercises to get the ball rolling.\n
# 15   I've always wanted to start writing (in a totally amateur way), but whenever I want to start something I instantly get blocked having a lot of questions and doubts.\nAre there some resources on how to start becoming a writer?\nI'm thinking something with tips and easy exercises to get the ball rolling.\n
# 79   I've always wanted to start writing (in a totally amateur way), but whenever I want to start something I instantly get blocked having a lot of questions and doubts.\nAre there some resources on how to start becoming a writer?\nI'm thinking something with tips and easy exercises to get the ball rolling.\n
# 123  I've always wanted to start writing (in a totally amateur way), but whenever I want to start something I instantly get blocked having a lot of questions and doubts.\nAre there some resources on how to start becoming a writer?\nI'm thinking something with tips and easy exercises to get the ball rolling.\n
# 254  I've always wanted to start writing (in a totally amateur way), but whenever I want to start something I instantly get blocked having a lot of questions and doubts.\nAre there some resources on how to start becoming a writer?\nI'm thinking something with tips and easy exercises to get the ball rolling.\n
#
#      text_len_question  Score_question  AcceptedAnswerId_question
# Id
# 8                352.0            32.0                       15.0
# 15               352.0            32.0                       15.0
# 79               352.0            32.0                       15.0
# 123              352.0            32.0                       15.0
# 254              352.0            32.0                       15.0

# %%
has_accepted_answer = df[df["is_question"] & ~(df["AcceptedAnswerId"].isna())]
received_answers = df[df["is_question"] & (df["AnswerCount"]!=0)]
no_answers = df[df["is_question"] & (df["AcceptedAnswerId"].isna()) & (df["AnswerCount"]==0)]

print("총 질문: %s개, 1개 이상의 답변을 가진 질문: %s개, 답변이 채택된 질문: %s개" % (
    len(df[df["is_question"]]),
    len(received_answers),
    len(has_accepted_answer)))
# Out:
# 총 질문: 7971개, 1개 이상의 답변을 가진 질문: 7827개, 답변이 채택된 질문: 4124개

# %%
fig = plt.figure(figsize=(16,10))
fig.suptitle("Distribution of question scores")
plt.xlabel("Question scores")
plt.ylabel("Number of questions")
df["Score"].hist(bins=200);

# %%
fig = plt.figure(figsize=(16,10))
fig.suptitle("Distribution of question length for sentences")
plt.xlabel("Words per question")
plt.ylabel("Number of questions")
q_len = plt.hist(df["text_len"],  bins=2000,log=False)

# %%
fig = plt.figure(figsize=(16,10))
fig.suptitle(
    "Distribution of question length for sentences shorter than 2000 words")
plt.xlabel("Words per question")
plt.ylabel("Number of questions")
q_len_trunc = plt.hist(df[df["text_len"]<2000]["text_len"], bins=200, log=False)

# %%
high_score = df["Score"] > df["Score"].median()
# 아주 긴 질문을 제외힙니다
normal_length = df["text_len"] < 2000

ax = df[df["is_question"] & high_score & normal_length]["text_len"].hist(
    bins=60,
    density=True,
    histtype="step",
    color="orange",
    linewidth=3,
    grid=False,
    figsize=(16, 10),
)

df[df["is_question"] & ~high_score & normal_length]["text_len"].hist(
    bins=60,
    density=True,
    histtype="step",
    color="purple",
    linewidth=3,
    grid=False,
)

handles = [
    Rectangle((0, 0), 1, 1, color=c, ec="k") for c in ["orange", "purple"]
]
labels = ["High score", "Low score"]
plt.legend(handles, labels)
ax.set_xlabel("Sentence length (characters)")
ax.set_ylabel("Percentage of sentences");

# %%
fig = plt.figure(figsize=(16,10))
fig.suptitle("Distribution of number of answers")
plt.xlabel("Number of answers")
plt.ylabel("Number of questions")
hist = df[df["is_question"]]["AnswerCount"].hist(bins=40)

# %%
scatter = df[df["is_question"]][["Score", "AnswerCount"]].plot(x="Score", y="AnswerCount", 
                                                               kind="scatter",
                                                              figsize=(16, 10))
ax.set_xlabel("Score")
ax.set_ylabel("Num answers")
scatter.set_title("Answer counts as a function of question score");

# %%
fig = plt.figure(figsize=(16,10))
fig.suptitle("Distribution of number of answers for high and low score questions")
plt.xlim(-5,80)

ax = df[df["is_question"] &
        (df["Score"] > df["Score"].median())]["AnswerCount"].hist(bins=60,
                                                          density=True,
                                                          histtype="step",
                                                          color="orange",
                                                          linewidth=3,
                                                          grid=False,
                                                          figsize=(16, 10))

df[df["is_question"] &
   ~(df["Score"] > df["Score"].median())]["AnswerCount"].hist(bins=60,
                                                     density=True,
                                                     histtype="step",
                                                     color="purple",
                                                     linewidth=3,
                                                     grid=False)

handles = [Rectangle((0, 0), 1, 1, color=c, ec="k") for c in
           ["orange", "purple"]]
labels = ["High score", "Low score"]
plt.legend(handles, labels)
ax.set_xlabel("Num answers")
ax.set_ylabel("Percentage of sentences");
